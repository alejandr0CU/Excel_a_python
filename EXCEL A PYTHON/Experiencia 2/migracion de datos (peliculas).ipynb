# %% [markdown]
# <center> <h1>Universidad Nacional de San Agustín de Arequipa</h1> </center>
# <center> <h1>Escuela Profesional de Ingeniería de Telecomunicaciones</h1> </center>
#
# <center> <h1> </h1> </center>
#
# <center><img src="https://user-images.githubusercontent.com/19308295/115939517-f1c6fe80-a463-11eb-989c-812ab4942586.png" width="380" height="4200"></center>

# %% [markdown]
# <center> <h1>Integrantes:</h1> </center>

# %% [markdown]
# <center> <h1>Boza Anampa, Diego Alexander</h1> </center>
#
# <center> <h1>Cáceres Ramos, Molly Tamara</h1> </center>
#
# <center> <h1>Camargo Calatayud, Alejandro Victor Therry</h1> </center>
#
# <center> <h1>Ccoa Arque, Ronaldo</h1> </center>
#
# <center> <h1>Huamani Quispe, Elisban</h1> </center>
#
# <center> <h1>Mamani Alvarez, Rudy</h1> </center>

# %% [markdown]
# <center> <h1>Arequipa-Perú</h1> </center>
# <center> <h1>2023</h1> </center>

# %%
import pandas as pd

df=pd.read_csv('archive/movies_dataset.csv')
df
# Out:
#                      genre_ids      id original_language  \
# 0      [16, 10751, 12, 14, 35]  502356                en
# 1                 [28, 80, 53]  385687                en
# 2                 [53, 27, 14]  713704                en
# 3                [28, 12, 878]  640146                en
# 4                     [28, 53]  552688                en
# ...                        ...     ...               ...
# 11995                     [18]  493622                hi
# 11996              [18, 10749]   75352                hi
# 11997                     [35]  471364                hi
# 11998                       []  143734                hi
# 11999                  [10749]  265289                hi
#
#                                                 overview  popularity  \
# 0      While working underground to fix a water main,...    8374.440
# 1      Over many missions and against impossible odds...    6742.222
# 2      Three siblings find an ancient vinyl that give...    3842.290
# ...

# %%
df.head()
# Out:
#                  genre_ids      id original_language  \
# 0  [16, 10751, 12, 14, 35]  502356                en
# 1             [28, 80, 53]  385687                en
# 2             [53, 27, 14]  713704                en
# 3            [28, 12, 878]  640146                en
# 4                 [28, 53]  552688                en
#
#                                             overview  popularity release_date  \
# 0  While working underground to fix a water main,...    8374.440   2023-04-05
# 1  Over many missions and against impossible odds...    6742.222   2023-05-17
# 2  Three siblings find an ancient vinyl that give...    3842.290   2023-04-12
# 3  Super-Hero partners Scott Lang and Hope van Dy...    3353.957   2023-02-15
# 4  A deadly female assassin comes out of hiding t...    2930.887   2023-05-04
#
#                                title  vote_average  vote_count  \
# 0        The Super Mario Bros. Movie           7.7        3163
# ...

# %%
df.tail()
# Out:
#          genre_ids      id original_language  \
# 11995         [18]  493622                hi
# 11996  [18, 10749]   75352                hi
# 11997         [35]  471364                hi
# 11998           []  143734                hi
# 11999      [10749]  265289                hi
#
#                                                 overview  popularity  \
# 11995  A cold-blooded contract killer hires the servi...       1.438
# 11996  Subeer Kumar (Amitabh) is well on his way to b...       1.437
# 11997  Comedy movie is about a Punjabi and Gujarati f...       1.436
# 11998  A con-man/thief robs a suitcase containing exp...       1.436
# 11999  Purani Jeans is a film based on the belief tha...       1.434
#
#       release_date                    title  vote_average  vote_count  \
# 11995   2006-07-21               The Killer           2.8           4
# 11996   1973-07-27                 Abhimaan           7.1          16
# ...

# %%
pl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   genre_ids          12000 non-null  object
#  1   id                 12000 non-null  int64
#  2   original_language  12000 non-null  object
#  3   overview           11971 non-null  object
#  4   popularity         12000 non-null  float64
#  5   release_date       11978 non-null  object
#  6   title              12000 non-null  object
#  7   vote_average       12000 non-null  float64
#  8   vote_count         12000 non-null  int64
#  9   genres             11875 non-null  object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 937.6+ KB

# %%
df.sort_values('popularity')
# Out:
#                      genre_ids      id original_language  \
# 11999                  [10749]  265289                hi
# 11998                       []  143734                hi
# 11997                     [35]  471364                hi
# 11996              [18, 10749]   75352                hi
# 11994                     [53]  761510                hi
# ...                        ...     ...               ...
# 4                     [28, 53]  552688                en
# 3                [28, 12, 878]  640146                en
# 2                 [53, 27, 14]  713704                en
# 1                 [28, 80, 53]  385687                en
# 0      [16, 10751, 12, 14, 35]  502356                en
#
#                                                 overview  popularity  \
# 11999  Purani Jeans is a film based on the belief tha...       1.434
# 11998  A con-man/thief robs a suitcase containing exp...       1.436
# 11997  Comedy movie is about a Punjabi and Gujarati f...       1.436
# ...

# %%
df.sort_values('vote_average')
# Out:
#                 genre_ids       id original_language  \
# 924          [28, 12, 14]   572802                en
# 11165         [10749, 53]   862508                hi
# 11720         [18, 10749]   427386                hi
# 4409   [35, 27, 80, 9648]  1123503                en
# 11175             [10749]   850928                hi
# ...                   ...      ...               ...
# 11807     [28, 18, 10749]   338644                hi
# 11597                  []   241156                hi
# 11340         [28, 10770]   619865                hi
# 11691             [10749]   356416                hi
# 11437         [80, 10749]   365585                hi
#
#                                                 overview  popularity  \
# 924    When an ancient power is unleashed, Aquaman mu...      41.034
# 11165  Desperate to leave her parents' house and star...       2.373
# 11720  An ambitious girl achieves her goal of leading...       1.669
# ...

# %%
df.shape
# Out:
# (12000, 10)

# %%
df_filtrado = df[df['original_language'] == 'en']
df_filtrado
# Out:
#                     genre_ids      id original_language  \
# 0     [16, 10751, 12, 14, 35]  502356                en
# 1                [28, 80, 53]  385687                en
# 2                [53, 27, 14]  713704                en
# 3               [28, 12, 878]  640146                en
# 4                    [28, 53]  552688                en
# ...                       ...     ...               ...
# 9995                     [18]  300687                en
# 9996                 [35, 18]   36208                en
# 9997             [27, 18, 53]  116811                en
# 9998             [18, 53, 12]   70954                en
# 9999                 [18, 53]   21635                en
#
#                                                overview  popularity  \
# 0     While working underground to fix a water main,...    8374.440
# 1     Over many missions and against impossible odds...    6742.222
# 2     Three siblings find an ancient vinyl that give...    3842.290
# ...

# %%
df.shape
# Out:
# (12000, 10)

# %% [markdown]
# ### Despues de esto recien podemos tratar datos

# %%
#filtrando las de comedia y obteniendo las mas populares
df_comedia=df_filtrado[df_filtrado['genres'] == 'Comedy']
df_comedia.sort_values('popularity')
# Out:
#      genre_ids       id original_language  \
# 9990      [35]    13667                en
# 9925      [35]     5894                en
# 9888      [35]    52736                en
# 9851      [35]  1093247                en
# 9828      [35]    14475                en
# ...        ...      ...               ...
# 393       [35]   346698                en
# 376       [35]    18785                en
# 350       [35]    87584                en
# 305       [35]   109418                en
# 276       [35]   800937                en
#
#                                                overview  popularity  \
# 9990  High school student Lane Meyer sinks into suic...       9.350
# 9925  Auggie runs a small tobacco shop in Brooklyn, ...       9.383
# 9888  Three middle-aged daddies visit California to ...       9.409
# 9851  A chaotic intervention. An action-packed stay ...       9.431
# 9828  When the owner of a struggling used car lot is...       9.443
# ...

# %%
#filtrando las de Action y obteniendo las mas populares
df_accion=df_filtrado[df_filtrado['genres'] == 'Action']
df_accion.sort_values('popularity')
# Out:
#      genre_ids       id original_language  \
# 9923      [28]   427910                en
# 9922      [28]   724717                en
# 9913      [28]    38940                en
# 9661      [28]    46103                en
# 9434      [28]    34309                en
# ...        ...      ...               ...
# 532       [28]    67398                en
# 395       [28]   811592                en
# 154       [28]   965839                en
# 50        [28]   842945                en
# 38        [28]  1048300                en
#
#                                                overview  popularity  \
# 9923  During a rescue mission, a team of Navy Seals ...       9.383
# 9922  Secret-service agent Vic Davis is on his way t...       9.383
# 9913  Nick Gunar is a burnt-out, jaded and hard-up f...       9.391
# 9661  A hard core Interpol Agent is assigned to an E...       9.552
# 9434  Sgt. James Dunn, who is wrongly accused of ass...       9.721
# ...

# %%
df_ordenado = df.sort_values(['vote_count'])
df_ordenado
# Out:
#                genre_ids       id original_language  \
# 2784                [27]  1126748                en
# 10158                 []  1038487                hi
# 11710                 []   300748                hi
# 10094               [18]  1121330                hi
# 10074        [18, 10751]  1114628                hi
# ...                  ...      ...               ...
# 215        [878, 28, 12]    24428                en
# 104    [28, 12, 14, 878]    19995                en
# 378     [18, 28, 80, 53]      155                en
# 150        [12, 18, 878]   157336                en
# 377        [28, 878, 12]    27205                en
#
#                                                 overview  popularity  \
# 2784   Trapped in an abandoned house, a nameless man ...      20.664
# 10158  Aazam is a Hindi feature film, set in the unde...       7.682
# 11710  After completing his college, dark-skinned Adi...       1.682
# ...
